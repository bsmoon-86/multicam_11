# %%
# 라이브러리 설치 
# !pip install matplotlib

# %%
# 라이브러리 로드 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# 현재 컴퓨터의 os 확인하기 위해 라이브러리 로드 
import platform

# %%
# 라인 그래프 생성 -> 선 그래프 
# plt 안에 plot() 함수를 이용
# 첫번째 매개변수가 가변의 인자를 받는 형태로 이루어져있다. 
# 인자를 1개만 입력하면 그래프의 y축의 데이터가 입력 (x축은 0부터 1씩 증가하는 기본값)
plt.plot( [5,4,3,2,1])
# plt안에 show() -> 그래프를 보여준다. ( ipynb 에서는 사용을 안 해도 그래프는 출력 )
plt.show()

# %%
# 인자가 2개 경우 : 첫번째 인자가 x축의 데이터, 두번째 인자가 y축의 데이터 
# 첫번째 인자의 길이와 두번째 인자의 길이가 같아야 한다. 
plt.plot([1,2,3,4], [70, 50, 100, 90])

plt.show()

# %%
# plt -> 도화지를 생성 ( 도화지의 크기를 지정, 도화지의 영역의 개수를 지정 )
# plt.plot() -> 선 그래프를 추가 
# plt.option() -> 추가적인 디자인이나 범위를 설정, x축의 이름이나, y축의 이름, 그래프의 이름 등을 지정
# plt.show() -> 결과물을 보여준다. (보여주고 -> 도화지는 초기화 )

# %%
x = [1,2,3,4]
y = [70, 80, 100, 60]

# %%
# 선의 종류를 변경
plt.plot(x, y, '--')
plt.show()
# 선의 색상을 변경
plt.plot(x, y, 'r')
plt.show()

# %%
# 선의 색상과 종류를 변경 
plt.plot(x, y, 'r--')

# %%
plt.plot(x , y)
plt.plot(x, [100, 60, 80, 40], 'r--')
plt.show()

# %%
# 그래프의 이름과 x축 y축에 이름을 지정 
plt.plot(x, y)
# 그래프의 이름은 지정 
plt.title('그래프 제목')
# x축의 이름을 지정 
plt.xlabel('X')
# y축의 이름을 지정 
plt.ylabel('Y')

plt.show()

# %%
# matplotlib 기본 설정으로 되어있는 폰트체가 한글을 지원하지 않는 폰트를 사용
# matplotlib에 폰트 설정을 변경 

# MAC, windows는 폰트의 종류가 다르다. 
# platform.system() -> os가 윈도우 경우네는 Windows 출력, MAC의 경우에는 Darwin 출력

if platform.system() == 'Darwin':
    # MAC인 경우
    plt.rc( 'font', family = 'AppleGothic' )
else:
    plt.rc('font', family = 'Malgun Gothic')

# %%
plt.plot(x, y)
plt.title('그래프 제목')
plt.show()

# %%
plt.plot(x, [-30, 0, -20, 50])
plt.show()

# %%
# 마이너스 기호의 깨짐 방지 
plt.rc('axes', unicode_minus = False)
# plt.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(x, [-30, 0, -20, 50])
plt.show()

# %%
# 하나의 영역에서 y축의 데이터가 2개 이상인 경우 -> 각각의 데이터들이 어떤 데이터인지 의미를 알아야된다. 
# 범례 추가 
x = [1,2,3]
y1 = [10, 6, 3]
y2 = [5, 8, 17]
plt.plot(x, y1)
plt.plot(x, y2)

# 범례를 추가 -> 각각의 데이터의 설명 
# loc 매개변수 : 범례의 위치를 지정 
plt.legend( ['a', 'b'] , loc = 'upper right')

plt.show()

# %%
# 막대 그래프 (수직)
plt.bar(x, y1)
plt.show()

# %%
# 막대 그래프 (수평)
plt.barh(x, y1)
plt.show()

# %%
# 막대그래프에서 막대의 색상과 너비를 조정 
plt.bar(x, y1, width=0.4, color=['red', 'green'])
plt.show()

# %%
# 막대 그래프에서 특정 막대를 선택해서 색상을 변경 
bar_graph = plt.bar(x, y1)

# bar_graph 에서 2번째 막대[index 1]의 색상을 변경 
# 색상은 이름, Hex 코드 사용이 가능
bar_graph[1].set_color("#5CA21F")

plt.show()

# %%
# 산점도 그래프 -> 데이터의 분포도를 확인하기 위한 그래프( 데이터 간의 상관관계를 확인 )
# 랜덤 데이터 100개씩 무작위하게 생성 
x = np.random.random(100)
y = np.random.random(100)

# %%
plt.scatter(x, y)

plt.show()

# %%
# pandas를 이용해서 데이터셋을 하나 로드 (drinks.csv)
df = pd.read_csv("../csv/drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
# 결측치의 개수를 확인 
df.isna().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
# 결측치가 포함된 데이터를 출력 
# 조건식 : continent에 결측치인 (인덱스의 조건식)
flag = df['continent'].isna()
df.loc[flag, ]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
# 결측치의 모든 데이터를 OT (기타 대륙) 대체
df.fillna('OT', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
# 과연 맥주 소비량, 위스키 소비량, 와인 소비량 순수알콜양 간의 상관계수가 어떻게 되는가?
# 상관계수를 구하는 함수 존재 -> corr(상관계수식 지정)
# 2번째 컬럼부터 마지막에서 1번째 컬럼 전까지 
df.iloc[:, 1:-1] 
# df.loc[:, 'beer_servings' : 'total_litres_of_pure_alcohol']
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
df.iloc[:, 1:-1].corr('pearson')
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# 맥주의 소비량과 순수알콜량의 상관계수가 0.8로 높은 수치 
# 산점도 그래프로 확인 
x = df['beer_servings']
y = df['total_litres_of_pure_alcohol']

plt.scatter(x, y)

plt.show()

# %%
# 상관계수가 낮은 위스키 소비량과 와인 소비량을 산점도 확인 
x = df['spirit_servings']
y = df['wine_servings']

plt.scatter(x, y)

plt.show()

# %% [markdown]
# 1. 컬럼의 이름들을 변경 -> [국가, 맥주소비량, 위스키소비량, 와인소비량, 순수알콜, 대륙]
# 2. 파생변수 -> '총술소비량' -> 맥주소비량 + 위스키소비량 + 와인소비량
# 3. 파생변수 -> '도수' -> (순수알콜 / 총술소비량) * 100
# 4. 대륙 별 그룹화를 하여 도수의 평균을 구한다 -> 가장 독한 술을 먹는 대륙은 어디인가?

# %%
# 컬럼 이름 변경 -> columns에 접근해서 데이터 대입 // rename() 함수를 이용해서 변경
df.columns = ['국가', '맥주소비량', '위스키소비량', '와인소비량', '순수알콜', '대륙']

# %%
df.head(1)
# Out:
#             국가  맥주소비량  위스키소비량  와인소비량  순수알콜  대륙
# 0  Afghanistan      0       0      0   0.0  AS

# %%
# 파생변수  -> dict에서 key:value 추가하는 방식과 같다. 
df['총술소비량'] = df['맥주소비량'] + df['위스키소비량'] + df['와인소비량']

# %%
# sum() 함수를 활용
df['총술소비량2'] = df.loc[:, '맥주소비량' : '와인소비량'].sum(axis=1)

# %%
df.head()
# Out:
#             국가  맥주소비량  위스키소비량  와인소비량  순수알콜  대륙  총술소비량  총술소비량2
# 0  Afghanistan      0       0      0   0.0  AS      0       0
# 1      Albania     89     132     54   4.9  EU    275     275
# 2      Algeria     25       0     14   0.7  AF     39      39
# 3      Andorra    245     138    312  12.4  EU    695     695
# 4       Angola    217      57     45   5.9  AF    319     319

# %%
# 총술소비량을 생성한 이유는 도수 컬럼을 생성하기 위함
df['도수'] = ( df['순수알콜'] / df['총술소비량'] ) * 100

# %%
df.head()
# Out:
#             국가  맥주소비량  위스키소비량  와인소비량  순수알콜  대륙  총술소비량  총술소비량2        도수
# 0  Afghanistan      0       0      0   0.0  AS      0       0       NaN
# 1      Albania     89     132     54   4.9  EU    275     275  1.781818
# 2      Algeria     25       0     14   0.7  AF     39      39  1.794872
# 3      Andorra    245     138    312  12.4  EU    695     695  1.784173
# 4       Angola    217      57     45   5.9  AF    319     319  1.849530

# %%
# 도수 결측치 부분은 0으로 채워준다. 
df['도수'] = df['도수'].fillna(0)

# %%
# 도수가 0인 데이터를 제외하고 대륙 별 도수의 평균을 구해보자 
df.loc[
    df['도수'] > 0, 
    ['대륙', '도수']
].groupby('대륙').mean()
# Out:
#           도수
# 대륙
# AF  5.272516
# AS  1.945398
# EU  1.834226
# OC  1.802179
# OT  1.785407
# SA  1.786790

# %%
# seaborn 라이브러리 설치 
# !pip install seaborn

# %%
# 히트맵 생성 
# 상관계수 corr() 을 이용하여 계산
corr = df.loc[:, "맥주소비량" : '순수알콜'].corr('pearson')
corr
# Out:
#            맥주소비량    위스키소비량     와인소비량      순수알콜
# 맥주소비량   1.000000  0.458819  0.527172  0.835839
# 위스키소비량  0.458819  1.000000  0.194797  0.654968
# 와인소비량   0.527172  0.194797  1.000000  0.667598
# 순수알콜    0.835839  0.654968  0.667598  1.000000

# %%
import seaborn as sns

# %%
# 그래프 사이즈를 변경 
plt.figure(figsize=(12, 8))

# corr의 데이터를 이용해서 히트맵 
# seaborn 라이브러리 안에 heatmap() 함수를 이용
sns.heatmap(
    data = corr.values, 
    annot = True,       # 주석 표시 유무
    square= True,       # 히트탭 정사각형 표시 유무
    fmt = '0.3f',       # 주석의 소수점 자리수를 지정
    annot_kws = {'size' : 20},  # 주석의 환경 설정 ( 글자의 크기를 변경 ) 
    cbar = False,       # 사이드바 표시 유무
    cmap = 'Greens',    # 히트맵의 색상을 변경 
    xticklabels= ['맥주', '위스키', '와인', '순수알콜'],    # x축의 이름을 재지정
    yticklabels= ['맥주', '위스키', '와인', '순수알콜']     # y축의 이름을 재지정
)

plt.show()

# %%
# 데이터 분포도(산점도)
sns.pairplot(
    df.loc[:, '맥주소비량' : '순수알콜'], 
    corner = True,          # 중복이 되는 산점도 그래프 제거 
    kind = 'reg',           # 추세선 추가
    plot_kws= {
        'line_kws' : {
            'color' : 'red'   # 추세선의 색상을 변경 
        }
    }
)

plt.show()

# %%
# 과연 우리나라는 총 술소비량이 전세계 몇위쯤 될것인가?
# 총술소비량을 기준으로 내림차순 정렬 
# sort_values() 함수를 이용 -> 기본값으로는 오름차순 정렬 -> ascending 매개변수를 False 변경 
df.sort_values('총술소비량', ascending=False, inplace=True)

# %%
# 한국의 순위는 몇위인가? -> 인덱스를 초기화하고 기존의 인덱스를 제거 
df.reset_index(drop=True, inplace=True)

# %%
# 순위 -> 위치 값에 + 1
# 국가의 이름이 'South Korea' 인 데이터를 추출해서 인덱스를 확인 
flag = df['국가'] == 'South Korea'
korea_index = df.loc[flag, ].index[0]
korea_rank = korea_index + 1

# %%
# 한국의 총술소비량 데이터 저장 
korea_value = df.loc[korea_index, '총술소비량']

# %%
# 모든 국가의 총술소비량 데이터를 이용해서 막대그래프 생성 
x = df.index
y = df['총술소비량']

flag = df['국가'] == 'South Korea'
korea_index = df.loc[flag, ].index[0]
korea_rank = korea_index + 1
korea_value = df.loc[korea_index, '총술소비량']

# 그래프 사이즈를 변경 
plt.figure(figsize=(20, 8))
# 국가별 막대 그래프를 그리고 한국의 막대의 색상을 변경한 뒤 주석을 달아서 한국이 몇위이고 수치가 몇인가?
bar_graph = plt.bar(x, y)

# 한국 위치의 막대를 선택해서 색상을 빨간색으로 변경 
bar_graph[korea_index].set_color('red')

# 그래프에 주석을 추가 (화살표로 주석이 나타내는 부분을 표시)
plt.annotate(
    f"South Korea \n rank : {korea_rank} \n 총술소비량 : {korea_value}",    # 주석에 들어갈 텍스트 지정
    xy = (korea_index, korea_value),                                      # 주석이 어느 부분을 설명하는가?(좌표)
    xytext= ( korea_index + 10, korea_value + 150 ),                      # 주석 문구의 위치
    arrowprops= {                                                         # 주석과 해당 데이터의 위치를 화살표 연결
        'facecolor' : 'r',          # 화살표의 안쪽의 색상을 지정
        'edgecolor' : 'black',      # 화살표 외부의 색상을 선택
        'headwidth' : 20,           # 화살표 머리의 너비를 지정
        'headlength' : 20,          # 화살표 머리의 길이
        'width' : 10,               # 화살표 꼬리의 너비
        'shrink' : 0.1              # 화살표와 xy, xytext간의 간격 조정
    }, 
    fontsize = 20                   # 주석의 크기를 지정
)

# plt.xticks(rotation = 45)
plt.show()

# %%
# 도수를 기준으로 해서 그래프를 생성 주석을 추가 

df.sort_values('도수', ascending=False, inplace=True)

df.reset_index(drop=True, inplace=True)

# %%
# South Korea의 인덱스의 값을 추출 , 인덱스 값에 +1 한 데이터를 저장 
# South Korea의 도수 데이터를 추출하여 저장 
korea_index = df.loc[ df['국가'] == 'South Korea', ].index[0]
korea_index
# Out:
# np.int64(14)

# %%
korea_rank = korea_index + 1

# %%
# 랭크 함수 -> rank() -> 오름차순정렬순으로 ranking 생성 
# ascending 매개변수를 False 변경하면 내림차순 정렬순으로 ranking 생성
# method 매개변수 -> 동점인 데이터들의 순위를 어떻게 매길것인가?
    # average(기본값) : 순위의 평균값을 생성 (2위 데이터가 2개라면 2.5위 )
    # min : 동점자 들의 낮은 순위로 생성 (스포츠에서 순위를 매기는 방식) ( 공동 2위, 다음 순위 4위 )
    # max : 돔점자 들의 높은 순위로 생성 ( 1위 -> 공동 3위 -> 4위 )
    # first : 데이터 상의 먼저 나온 순서로 순위를 지정 ( sort_values() -> reset_index() 방식과 동일 )
    # dense : min과 흡사, 동점자들은 낮은 순위로 지정, 다음 순위가 +1 순위 (공동 2위, 다음 순위가 3위)

# %%
korea_value = df.loc[korea_index, '도수']
korea_value
# Out:
# np.float64(5.93939393939394)

# %%
# korea_value를 반올림하여 소수점 2자리까지만 유지 
# round() 함수 이용
korea_value = round(korea_value, 2)
korea_value
# Out:
# np.float64(5.94)

# %%
x = df.index
y = df['도수']

# 그래프 사이즈를 변경 
plt.figure(figsize=(20, 8))
# 국가별 막대 그래프를 그리고 한국의 막대의 색상을 변경한 뒤 주석을 달아서 한국이 몇위이고 수치가 몇인가?
bar_graph = plt.bar(x, y)

# 한국 위치의 막대를 선택해서 색상을 빨간색으로 변경 
bar_graph[korea_index].set_color('red')

# 그래프에 주석을 추가 (화살표로 주석이 나타내는 부분을 표시)
plt.annotate(
    f"South Korea \n rank : {korea_rank} \n 도수 : {korea_value}",    # 주석에 들어갈 텍스트 지정
    xy = (korea_index, korea_value),                                      # 주석이 어느 부분을 설명하는가?(좌표)
    xytext= ( korea_index + 10, korea_value + 5 ),                      # 주석 문구의 위치
    arrowprops= {                                                         # 주석과 해당 데이터의 위치를 화살표 연결
        'facecolor' : 'r',          # 화살표의 안쪽의 색상을 지정
        'edgecolor' : 'black',      # 화살표 외부의 색상을 선택
        'headwidth' : 20,           # 화살표 머리의 너비를 지정
        'headlength' : 20,          # 화살표 머리의 길이
        'width' : 10,               # 화살표 꼬리의 너비
        'shrink' : 0.1              # 화살표와 xy, xytext간의 간격 조정
    }
)

# plt.xticks(rotation = 45)

# 만들어진 그래프를 파일로 저장 -> PPT, word 문서에 넣어준다. 
# savefig() 함수를 이용해서 파일로 저장 
# fname 매개변수 : 파일의 이름을 지정 (경로 지정)
# dpi 매개변수 : 해상도 지정 -> 기본값은 100 -> 숫자가 올라가면 고해상도 
# bbox_inches 매개변수 : 그래프 주변에 여백을 제거 'tight' 여백 제거 하고 저장 
# transparent 매개변수 : 배경을 제거할것인가? bool
# facecolot 매개변수 : 배경의 색을 지정 (transparent 값이 False인 경우 사용 가능)
plt.savefig('../a.png', dpi = 300, bbox_inches = 'tight', transparent = False, facecolor = 'yellow')


plt.show()
