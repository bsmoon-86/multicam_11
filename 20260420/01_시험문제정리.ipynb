# %%
a = [1,2,3]
# list 안에 insert 함수 -> list에 데이터를 대입 (위치와 데이터를 인자값으로 사용)
a.insert(2, 4)
print(a)
# Out:
# [1, 2, 4, 3]

# %%
# 튜플 (1,2,3)에 원소를 추가하려면? 
# 튜플의 특징은 한번 생성을 하면 수정(추가, 삭제) 작업 불가 -> 새로 생성

# %%
def func(x, acc=[]):
    # 2개의 매개변수가 존재 
    # acc 빈 리스트는 가변의 데이터 -> 기본값을 그대로 사용하면 데이터들을 유지 (주소값)
    acc.append(x)
    return acc

print(func(1))
print(func(2))
print(func(3, []))
# Out:
# [1]
# [1, 2]
# [3]

# %%
a = [1,2,3]
b = a       # 얕은 복사 
b[0] = 100  # b의 첫번째 원소를 100 대입 -> [100, 2, 3] -> a도 변한다. 
print(a)
# Out:
# [100, 2, 3]

# %%
# ZeroDivisionError -> 분모가 0인경우 발생하는 에러 코드

# %%
# 전역 변수와 지역 변수의 이름이 같을때, 함수 내부에서 지역 변수를 사용하려면?
x = 100

def func_1(a):
    # 지역변수 x를 생성
    x = 10
    
    return x + a

print(func_1(10))
print(x)
# Out:
# 20
# 100

# %%
# list[시작위치 : 종료위치] -> 시작위치 부터 종료위치 전까지 (종료 위치는 포함 x)
print([1,2,3,4,5][1:4])
# Out:
# [2, 3, 4]

# %%
# 논리 연산자 -> bool 데이터 
not(True and False)
# Out:
# True

# %%
# 강제적인 bool의 형태로 변환 
# 문자의 경우 -> 빈 문자열(False) 문자가 존재하면(True)
# 숫자의 경우 -> 0(False) 양수(True) 음수(True)
# 자료형데이터(튜플, 리스트, 딕셔너리) -> 원소가 존재하지 않으면(False) 존재하면(True)
bool("a")
# Out:
# True

# %%
# 파이썬에서 유효한 변수의 이름 
    # 공백이 존재하면 안된다. (공백 -> 독립적으로 실행)
    # 특수문자는 '_'을 제외하고 사용 금지 
    # 이름의 첫글자는 문자나 _를 사용해라 (숫자로 시작하지 말것)
    # 대 소문자 구분을 한다. (코드 문법적으로 많이 사용이 되는 부분 -> 각 회사(팀)별로 사용 규칙을 통일)

# %%
# class에서 문자열 클래스 변수 변경 
# @classmethod -> 데코레이터 함수
class Test:
    text = "Hello"

    def __init__(self, a):
        self.a = a

    def func_1(self, x):
        Test.text = x

# %%
class_1 = Test(10)
class_2 = Test(20)

# %%
print(class_1.text)
print(class_2.text)
# Out:
# Hello
# Hello

# %%
# class 변수 text를 변경하는 함수를 호출 
class_1.func_1('Hi')

# %%
print(class_1.text)
print(class_2.text)
# Out:
# Hi
# Hi

# %%
class Test2:
    text = 'Hello'

    # 일반적인 class 내부의 함수에서 첫번째 매개변수에는 생성이 된 class의 주소값이 입력(자동)
    def __init__(self, a):
        self.a = a
    
    # classmethod : 클래스의 이름에 접근할 수 있는 데코레이터 -> 
    # 함수에는 첫번째 매개변수에 클래스의 이름이 입력(자동)
    @classmethod
    def func_1(cls, x):
        # classmethod를 이용한 함수는 첫번째 매개변수명을 cls
        # cls에는 해당 class의 이름이 인자로 사용
        # 수정 중에 class 이름이 변하더라도 해당 cls는 그대로 유지가 가능 
        cls.text = x

# %%
class_3 = Test2(10)
class_4 = Test2(20)

# %%
print(class_3.text)
print(class_4.text)
# Out:
# Hello
# Hello

# %%
class_3.func_1('Hi')

# %%
print(class_3.text)
print(class_4.text)
# Out:
# Hi
# Hi
