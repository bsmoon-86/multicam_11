# %% [markdown]
# ### 라이브러리를 이용해서 데이터를 수집
# - yahoo finanace
#     - 글로벌 주식 및 회사 데이터를 로드
# - 한국거래소 정보를 가져오는 라이브러리 (pykrx)
#     - 한국 회사들에 대한 데이터 로드
#
# - 실시간 데이터는 불가능
#     - pykrx는 일별 주식 가격 조회
#     - yfinanace는 시간별로 조회 가능 (기간이 굉장히 짧음), 실시간은 아님(한 20분 ~ 30분 정도의 차이가 존재)
#
# - 실시간 데이터를 로드하려면 증권사 api 사용
#     - 증권사 계정이 존재 ( 개인 계정 가능 )
#         - 은행 계좌 등록
#         - 별도의 api key 발급

# %%
# 라이브러리 설치 
# !pip install yfinance pykrx

# %%
# 라이브러리 로드 
import yfinance as yf

# %%
# 특정 종목의 데이터를 가져온다. 
ticker1 = "005930.KS"
samsung = yf.Ticker(ticker1)

# %%
# history() -> 
# 주요 매개변수 peroid(기간 설정) -> 기본값 1d -> 5d, 1mo, 3mo, 6mo, 1y, 2y
# interval(주기) -> 
samsung.history(period='5d', interval = '1m')
# Out:
#                                Open      High       Low     Close  Volume  \
# Datetime
# 2026-04-17 09:00:00+09:00  217000.0  218000.0  217000.0  217250.0       0
# 2026-04-17 09:01:00+09:00  217250.0  218000.0  216500.0  216500.0  138510
# 2026-04-17 09:02:00+09:00  217000.0  217500.0  216500.0  216500.0   64171
# 2026-04-17 09:03:00+09:00  216500.0  217000.0  216000.0  216000.0  132867
# 2026-04-17 09:04:00+09:00  216500.0  216500.0  216000.0  216000.0   80982
# ...                             ...       ...       ...       ...     ...
# 2026-04-23 14:55:00+09:00  224500.0  225000.0  224500.0  224500.0   21110
# 2026-04-23 14:56:00+09:00  224500.0  225000.0  224500.0  224500.0   18468
# 2026-04-23 14:57:00+09:00  224500.0  225000.0  224500.0  224500.0   22205
# 2026-04-23 14:58:00+09:00  225000.0  225000.0  224500.0  225000.0   44561
# 2026-04-23 14:59:00+09:00  224750.0  225000.0  224750.0  224750.0   73362
#
#                            Dividends  Stock Splits
# Datetime
# 2026-04-17 09:00:00+09:00        0.0           0.0
# 2026-04-17 09:01:00+09:00        0.0           0.0
# 2026-04-17 09:02:00+09:00        0.0           0.0
# 2026-04-17 09:03:00+09:00        0.0           0.0
# 2026-04-17 09:04:00+09:00        0.0           0.0
# ...                              ...           ...
# 2026-04-23 14:55:00+09:00        0.0           0.0
# 2026-04-23 14:56:00+09:00        0.0           0.0
# 2026-04-23 14:57:00+09:00        0.0           0.0
# 2026-04-23 14:58:00+09:00        0.0           0.0
# 2026-04-23 14:59:00+09:00        0.0           0.0
#
# [1440 rows x 7 columns]

# %%
# 라이브러리로 이용중이지만 크롤링 -> 과도하게 사용시 아이피가 벤을 당하는 경우 발생

# %%
# 배당금 주식 분할 정보
samsung.actions

# %%
# pykrx 라이브러리 
from pykrx import stock

# %%
# 특정 날짜의 상장 종목을 모두 확인 
tickers = stock.get_market_ticker_list("20260401", market='KOSPI')
# Out:
# Error occurred in get_market_ticker_and_name: Expecting value: line 1 column 1 (char 0)
# []

# %%
stock.get_market_ticker_name('005930')
# Out:
# '삼성전자'

# %%
# OHLCV 확인 
stock.get_market_ohlcv("20260101", "20260423", "005930")
# Out:
#                 시가      고가      저가      종가       거래량       등락률
# 날짜
# 2026-01-02  120200  128500  120200  128500  30463279  7.172644
# 2026-01-05  134600  138600  133600  138100  42863376  7.470817
# 2026-01-06  135300  139300  132700  138900  45321341  0.579290
# 2026-01-07  143500  144400  137600  141000  46317413  1.511879
# 2026-01-08  138300  144500  138300  138800  41449329 -1.560284
# ...            ...     ...     ...     ...       ...       ...
# 2026-04-17  217000  218000  215000  216000  18079322 -0.689655
# 2026-04-20  214500  219000  213000  214500  17107741 -0.694444
# 2026-04-21  218000  220000  216000  219000  16752132  2.097902
# 2026-04-22  218500  222500  215500  217500  16823480 -0.684932
# 2026-04-23  223000  229500  216000  224500  33874721  3.218391
#
# [76 rows x 6 columns]

# %%
stock.get_market_fundamental_by_date('20260101', '20260423', '005930')
# Out:
# Error occurred in get_market_fundamental_by_date: Expecting value: line 1 column 1 (char 0)
# Empty DataFrame
# Columns: []
# Index: []

# %%
# !pip install finance-datareader

# %%
import FinanceDataReader as fdr

# %%
# KRX 전체 종목 확인 
tickers = fdr.StockListing("KRX")

# %%
tickers.head()
# Out:
#    Unnamed: 0    Code        ISU_CD      Name Market Dept    Close ChangeCode  \
# 0           0  005930  KR7005930003      삼성전자  KOSPI  NaN   224500          1
# 1           1  000660  KR7000660001    SK하이닉스  KOSPI  NaN  1225000          1
# 2           2  005935  KR7005931001     삼성전자우  KOSPI  NaN   156200          1
# 3           3  373220  KR7373220003  LG에너지솔루션  KOSPI  NaN   466500          2
# 4           4  005380  KR7005380001       현대차  KOSPI  NaN   532000          2
#
#    Changes  ChagesRatio     Open     High      Low    Volume         Amount  \
# 0     7000         3.22   223000   229500   216000  34525485  7739982934106
# 1     2000         0.16  1220000  1267000  1183000   5343871  6558016801135
# 2     4900         3.24   154500   160800   151500   4642008   729556414700
# 3   -18000        -3.72   481500   484000   460000    529996   248030525500
# 4    -9000        -1.66   547000   551000   525000   1089561   585221220000
#
#              Marcap      Stocks MarketId
# 0  1312489547496000  5846278608      STK
# 1   873060397125000   712702365      STK
# 2   125330381908600   802371203      STK
# 3   109161000000000   234000000      STK
# 4   108931131512000   204757766      STK

# %%
# 특정 종목의 가격 데이터 확인 
fdr.DataReader('005930', '2026-01-01', '2026-04-23')
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2026-01-02  120200  128500  120200  128500  30463279  0.071726
# 2026-01-05  134600  138600  133600  138100  42863376  0.074708
# 2026-01-06  135300  139300  132700  138900  45321341  0.005793
# 2026-01-07  143500  144400  137600  141000  46317413  0.015119
# 2026-01-08  138300  144500  138300  138800  41449329 -0.015603
# ...            ...     ...     ...     ...       ...       ...
# 2026-04-17  217000  218000  215000  216000  18079322 -0.006897
# 2026-04-20  214500  219000  213000  214500  17107741 -0.006944
# 2026-04-21  218000  220000  216000  219000  16752132  0.020979
# 2026-04-22  218500  222500  215500  217500  16823480 -0.006849
# 2026-04-23  223000  229500  216000  224500  33874721  0.032184
#
# [76 rows x 6 columns]

# %%
# 지수 확인 
# 코스피 KS11, 코스닥 KQ11
fdr.DataReader('KS11', '2026-01-01')

# %%
fdr.DataReader('AAPL', '2026-01-01')
# Out:
#                   Open        High         Low       Close    Volume  \
# 2025-12-31  273.059998  273.679993  271.750000  271.859985  27293600
# 2026-01-02  272.260010  277.839996  269.000000  271.010010  37838100
# 2026-01-05  270.640015  271.510010  266.140015  267.260010  45647200
# 2026-01-06  267.000000  267.549988  262.119995  262.359985  52352100
# 2026-01-07  263.200012  263.679993  259.809998  260.329987  48309800
# ...                ...         ...         ...         ...       ...
# 2026-04-16  266.799988  267.160004  261.269989  263.399994  43323100
# 2026-04-17  266.959991  272.299988  266.720001  270.230011  61436200
# 2026-04-20  270.329987  274.279999  270.290009  273.049988  36590200
# 2026-04-21  271.500000  272.799988  265.399994  266.170013  50209800
# 2026-04-22  267.820007  273.739990  266.869995  273.170013  43195700
#
#              Adj Close
# 2025-12-31  271.605835
# 2026-01-02  270.756653
# 2026-01-05  267.010162
# 2026-01-06  262.114716
# 2026-01-07  260.086609
# ...                ...
# 2026-04-16  263.399994
# 2026-04-17  270.230011
# 2026-04-20  273.049988
# 2026-04-21  266.170013
# 2026-04-22  273.170013
#
# [77 rows x 6 columns]

# %%
# 종목 비교 (종가를 기준으로 비교 )
fdr.DataReader("005930, 000660", '2026-01-01')
# Out:
#             005930   000660
# Date
# 2026-01-02  128500   677000
# 2026-01-05  138100   696000
# 2026-01-06  138900   726000
# 2026-01-07  141000   742000
# 2026-01-08  138800   756000
# ...            ...      ...
# 2026-04-17  216000  1128000
# 2026-04-20  214500  1166000
# 2026-04-21  219000  1224000
# 2026-04-22  217500  1223000
# 2026-04-23  224500  1225000
#
# [76 rows x 2 columns]

# %%
# 환율 
# 원/달러 환율
fdr.DataReader( 'USD/KRW', '2026' )
# Out:
#                    Open         High          Low        Close  Volume  \
# 2025-12-31  1439.550049  1449.199951  1437.369995  1437.910034     0.0
# 2026-01-01          NaN          NaN          NaN          NaN     NaN
# 2026-01-02  1440.810059  1446.630005  1439.040039  1443.640015     0.0
# 2026-01-05  1440.479980  1449.750000  1440.479980  1440.479980     0.0
# 2026-01-06  1445.380005  1449.010010  1442.150024  1445.560059     0.0
# ...                 ...          ...          ...          ...     ...
# 2026-04-19  1465.150024  1478.640015  1464.489990  1465.150024     0.0
# 2026-04-20  1471.069946  1479.119995  1466.910034  1469.260010     0.0
# 2026-04-21  1478.130005  1481.900024  1473.319946  1485.800049     0.0
# 2026-04-22  1480.189941  1484.380005  1477.079956          NaN     0.0
# 2026-04-23  1480.189941  1484.380005  1477.079956  1481.579956     0.0
#
#               Adj Close
# 2025-12-31  1437.910034
# 2026-01-01          NaN
# 2026-01-02  1443.640015
# 2026-01-05  1440.479980
# 2026-01-06  1445.560059
# ...                 ...
# 2026-04-19  1465.150024
# 2026-04-20  1469.260010
# 2026-04-21  1485.800049
# 2026-04-22          NaN
# 2026-04-23  1481.579956
#
# [83 rows x 6 columns]

# %%
# 업비트를 기준으로 코인의 시세 확인 가능 
fdr.DataReader( 'BTC/KRW', '2026' )
# Out:
#                    Open         High          Low        Close  \
# 2025-12-31  127251056.0  128625912.0  125872296.0  126359032.0
# 2026-01-01  126357904.0  128228088.0  126201040.0  128125224.0
# 2026-01-02  128126784.0  131267424.0  127352968.0  129751520.0
# 2026-01-03  129752040.0  131193360.0  128861992.0  130701440.0
# 2026-01-04  130701168.0  132301824.0  130689776.0  131862312.0
# ...                 ...          ...          ...          ...
# 2026-04-19  111089688.0  111851664.0  108205664.0  108284792.0
# 2026-04-20  108281704.0  112675592.0  108166352.0  111552512.0
# 2026-04-21  111552960.0  113112632.0  111365176.0  113521392.0
# 2026-04-22  113523528.0  117683976.0  112586536.0  115659384.0
# 2026-04-23  115644424.0  116065856.0  115093800.0  115545480.0
#
#                     Volume    Adj Close
# 2025-12-31  48849388374783  126359032.0
# 2026-01-01  27217219568001  128125224.0
# 2026-01-02  66933670074453  129751520.0
# 2026-01-03  29969144481743  130701440.0
# 2026-01-04  38615949707584  131862312.0
# ...                    ...          ...
# 2026-04-19  45350366307118  108284792.0
# 2026-04-20  58331844727240  111552512.0
# 2026-04-21  54199136446102  113521392.0
# 2026-04-22  71488057672440  115659384.0
# 2026-04-23  62739993067520  115545480.0
#
# [114 rows x 6 columns]

# %%
# !pip install matplotlib

# %%
# 그래프 
import matplotlib.pyplot as plt

# %%
# 하이닉스의 종가 기준 그래프 

df = fdr.DataReader("000660", '2025')
df

# %%
# 종가를 기준으로 그래프 생성 
df['Close'].plot( figsize=(12, 8), title='hynix close price' )
plt.grid(True)
plt.show()
