# %% [markdown]
# ### Optuna
# - 최적의 파라미터를 찾기 위한 라이브러리
# - create_study() 라는 내장 함수를 이용하여 특정 모델의 최적의 파라미터를 서치
# - GridSearchCV에 비해서 속도 면에서 우세
#     - GridSearchCV는 파라미터의 모든 조합을 fit하고 검증의 결과를 확인
#     - Optuna는 확률 기반 -> 모든 조합을 활용하지는 않는다.
# - 조합의 수 제어
#     - GridSearchCV : params로 제어
#     - Optuna : n_trials 매개변수로 제어

# %%
# 라이브러리 설치 
# !pip install optuna

# %%
import optuna 
from sklearn.datasets import load_iris
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score, make_scorer

# %%
# iris 데이터 로드 
X, y = load_iris(return_X_y=True)

# %%
# objective 함수를 생성 : 파라미터의 조합, 파이프, 폴드, 검증 방법 
def objective(trial):
    # SVC 모델의 파라미터 조합을 생성 
    # suggest_XXX
        # suggest_int, suggest_float : 정수, 실수 형태의 파라미터 조합 (시작값, 종료값, log매개변수)
            # log 매개변수 : False기본값, True로 변경하면 로그 스케일로 조합을 생성(실수형태에서 사용)
        # suggest_categorical : 특정 범주 조합 
    C = trial.suggest_float("C", 1e-3, 10.0, log=True)
    gamma = trial.suggest_float('gamma', 1e-4, 1.0, log=True)
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf'])
    model = SVC(C=C, gamma = gamma, kernel = kernel)

    pipe = Pipeline(
        [
            ('std', StandardScaler()), 
            ('clf', model)
        ]
    )
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    scores = cross_val_score(pipe, X, y, cv = cv, scoring= make_scorer(f1_score, average='macro'))

    return scores.mean()

# %%
study = optuna.create_study(
    direction= 'maximize', 
    study_name='class_ml_tuning'
)
study.optimize(
    objective, n_trials=30, show_progress_bar=True
)
# Out:
# [I 2026-06-11 10:37:21,291] A new study created in memory with name: class_ml_tuning
# Best trial: 7. Best value: 0.973266:  27%|██▋       | 8/30 [00:00<00:00, 46.84it/s]
# [I 2026-06-11 10:37:21,316] Trial 0 finished with value: 0.9337044631781474 and parameters: {'C': 0.02166626767068227, 'gamma': 0.8376963749871861, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9337044631781474.
# [I 2026-06-11 10:37:21,334] Trial 1 finished with value: 0.9661728917348785 and parameters: {'C': 2.0765503087483985, 'gamma': 0.00018723179638835256, 'kernel': 'linear'}. Best is trial 1 with value: 0.9661728917348785.
# [I 2026-06-11 10:37:21,352] Trial 2 finished with value: 0.911819643142836 and parameters: {'C': 0.026837831804044227, 'gamma': 0.638241255833996, 'kernel': 'linear'}. Best is trial 1 with value: 0.9661728917348785.
# [I 2026-06-11 10:37:21,375] Trial 3 finished with value: 0.8584153478324967 and parameters: {'C': 0.026311441371933524, 'gamma': 0.018087424902814436, 'kernel': 'rbf'}. Best is trial 1 with value: 0.9661728917348785.
# [I 2026-06-11 10:37:21,398] Trial 4 finished with value: 0.8651321398124466 and parameters: {'C': 0.0020429215319238228, 'gamma': 0.0020934036179410115, 'kernel': 'linear'}. Best is trial 1 with value: 0.9661728917348785.
# [I 2026-06-11 10:37:21,421] Trial 5 finished with value: 0.9599331662489557 and parameters: {'C': 9.052616042709372, 'gamma': 0.007872964873088348, 'kernel': 'rbf'}. Best is trial 1 with value: 0.9661728917348785.
# [I 2026-06-11 10:37:21,441] Trial 6 finished with value: 0.8848460711053253 and parameters: {'C': 0.527752284869703, 'gamma': 0.014422296506091916, 'kernel': 'rbf'}. Best is trial 1 with value: 0.9661728917348785.
# [I 2026-06-11 10:37:21,461] Trial 7 finished with value: 0.9732664995822891 and parameters: {'C': 0.7646576963443668, 'gamma': 0.0007085626024234787, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,486] Trial 8 finished with value: 0.8651321398124466 and parameters: {'C': 0.009653210929159196, 'gamma': 0.0003629238454250955, 'kernel': 'rbf'}. Best is trial 7 with value: 0.9732664995822891.
# Best trial: 16. Best value: 0.979849:  57%|█████▋    | 17/30 [00:00<00:00, 45.60it/s]
# [I 2026-06-11 10:37:21,506] Trial 9 finished with value: 0.9055161994992389 and parameters: {'C': 0.027596530300196015, 'gamma': 0.014371593995514792, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,530] Trial 10 finished with value: 0.9599331662489556 and parameters: {'C': 0.3109598229374987, 'gamma': 0.14285965040275903, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,553] Trial 11 finished with value: 0.9661728917348785 and parameters: {'C': 2.4069162436450573, 'gamma': 0.00011078478046000812, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,575] Trial 12 finished with value: 0.9599331662489557 and parameters: {'C': 0.45266469756486977, 'gamma': 0.0006957819464470534, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,595] Trial 13 finished with value: 0.9661728917348785 and parameters: {'C': 1.7778847972438205, 'gamma': 0.0001025893658276464, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,618] Trial 14 finished with value: 0.9464651527809422 and parameters: {'C': 0.12538735277974214, 'gamma': 0.0009467120367797505, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,641] Trial 15 finished with value: 0.9732664995822891 and parameters: {'C': 9.532758188815148, 'gamma': 0.0020713111485948675, 'kernel': 'linear'}. Best is trial 7 with value: 0.9732664995822891.
# [I 2026-06-11 10:37:21,663] Trial 16 finished with value: 0.9798486114275586 and parameters: {'C': 7.465607743848087, 'gamma': 0.0021932316689940363, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,686] Trial 17 finished with value: 0.9661728917348785 and parameters: {'C': 3.1917657308287355, 'gamma': 0.003582110718298172, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# Best trial: 16. Best value: 0.979849:  83%|████████▎ | 25/30 [00:00<00:00, 44.20it/s]
# [I 2026-06-11 10:37:21,707] Trial 18 finished with value: 0.9465664160401002 and parameters: {'C': 0.16034308057145846, 'gamma': 0.059354667310886025, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,731] Trial 19 finished with value: 0.9663805979595453 and parameters: {'C': 1.0522753483444545, 'gamma': 0.0007181054769639894, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,759] Trial 20 finished with value: 0.9661728917348785 and parameters: {'C': 4.663213614182249, 'gamma': 0.0041648698798111925, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,781] Trial 21 finished with value: 0.9732664995822891 and parameters: {'C': 9.878148164186575, 'gamma': 0.0020540958013138973, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,802] Trial 22 finished with value: 0.9661728917348785 and parameters: {'C': 5.460571727797458, 'gamma': 0.0013068427367870594, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,825] Trial 23 finished with value: 0.9728562668393061 and parameters: {'C': 1.324898972717501, 'gamma': 0.0003823551524048377, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,849] Trial 24 finished with value: 0.9732664995822891 and parameters: {'C': 0.8006530994467919, 'gamma': 0.005039042223141474, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,871] Trial 25 finished with value: 0.9661728917348785 and parameters: {'C': 5.078852723661384, 'gamma': 0.0016507849501664908, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# Best trial: 16. Best value: 0.979849: 100%|██████████| 30/30 [00:00<00:00, 44.13it/s]
# [I 2026-06-11 10:37:21,899] Trial 26 finished with value: 0.8651321398124466 and parameters: {'C': 0.14491004324672185, 'gamma': 0.0003489017920012862, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,919] Trial 27 finished with value: 0.9661728917348785 and parameters: {'C': 3.709628305619182, 'gamma': 0.05753916608136882, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,945] Trial 28 finished with value: 0.9732664995822891 and parameters: {'C': 8.762802884274056, 'gamma': 0.002937176581592543, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2026-06-11 10:37:21,970] Trial 29 finished with value: 0.8651321398124466 and parameters: {'C': 0.05225907877304544, 'gamma': 0.0005784321068623593, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9798486114275586.

# %%
# 최적의 파라미터 값을 출력 
study.best_params
# Out:
# {'C': 7.465607743848087, 'gamma': 0.0021932316689940363, 'kernel': 'linear'}

# %%
# 최적의 스코어 확인 
study.best_value
# Out:
# 0.9798486114275586
